# %%
from langchain_community.tools import DuckDuckGoSearchRun
search_tool = DuckDuckGoSearchRun()
result = search_tool.invoke('What is the current time , date and whether in Kashmir.Is it Day or Night.')
print(result)
# Out:
# /tmp/ipykernel_34844/3166423906.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.tools import DuckDuckGoSearchRun
# 8 Sept 2025 ... Jammu and Kashmir (abbr. J&K) is a region administered by India as a union territory consisting of the southern portion of the larger Kashmir region, ... 14 hours ago ... Current Local Time in Srinagar, Jammu and Kashmir, India ; Sunrise. 5:20 am ↑ 61° Northeast ; Sunset. 7:45 pm ↑ 299° Northwest ; Day length. 14 hours, 26 minutes - ... 5 hours ago ... Sunrise. 5:23 am ↑ 61° Northeast ; Sunset. 7:41 pm ↑ 299° Northwest ; Day length. 14 hours, 18 minutes -3s shorter ; Moon 64.0%. Set – 12:44 am. Rise – 1:55 pm. 14 May 2026 ... This has led to a noticeable drop in both daytime and night-time temperatures. On Sunday, Srinagar recorded a maximum temperature of 19.5°C, which is 7.5 ... 5 Apr 2026 ... JAMMU & KASHMIR WEATHER UPDATE 14 JUNE SUNDAY WEATHER BYUMAR CURRENT ... DATE JUNE 2026 THURSDAY TIME (UPDATED) 07:30 PM IST JAMMU & KASHMIR NEXT 6 HOURS ...

# %%
'pip install langchain-experimental'
# Out:
# Collecting langchain-experimental
#   Downloading langchain_experimental-0.4.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from langchain-experimental) (1.4.7)
# Requirement already satisfied: langchain-community<1.0.0,>=0.4.2 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from langchain-experimental) (0.4.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from langchain-community<1.0.0,>=0.4.2->langchain-experimental) (3.14.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from langchain-community<1.0.0,>=0.4.2->langchain-experimental) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from langchain-community<1.0.0,>=0.4.2->langchain-experimental) (1.0.8)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from langchain-community<1.0.0,>=0.4.2->langchain-experimental) (0.8.16)
# Requirement already satisfied: numpy>=2.1.0 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from langchain-community<1.0.0,>=0.4.2->langchain-experimental) (2.4.6)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from langchain-community<1.0.0,>=0.4.2->langchain-experimental) (2.14.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from langchain-community<1.0.0,>=0.4.2->langchain-experimental) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from langchain-community<1.0.0,>=0.4.2->langchain-experimental) (2.34.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from langchain-community<1.0.0,>=0.4.2->langchain-experimental) (2.0.51)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from langchain-community<1.0.0,>=0.4.2->langchain-experimental) (9.1.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (1.24.2)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (1.1.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-experimental) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-experimental) (0.0.17)
# Requirement already satisfied: packaging>=23.2.0 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-experimental) (26.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-experimental) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-experimental) (0.16.1)
# Requirement already satisfied: jsonpointer>=1.9 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain-experimental) (3.1.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (1.0.0)
# Requirement already satisfied: websockets>=15.0 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (0.25.0)
# Requirement already satisfied: anyio in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (4.14.0)
# Requirement already satisfied: certifi in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (1.0.9)
# Requirement already satisfied: idna in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (3.18)
# Requirement already satisfied: h11>=0.16 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from requests<3.0.0,>=2.32.5->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from requests<3.0.0,>=2.32.5->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (2.7.0)
# Requirement already satisfied: greenlet>=1 in /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (3.5.1)
# Downloading langchain_experimental-0.4.2-py3-none-any.whl (211 kB)
# Installing collected packages: langchain-experimental
# Successfully installed langchain-experimental-0.4.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.tools import ShellTool
shell_tool = ShellTool()
result = shell_tool.invoke('whoami')
print(result)
# Out:
# Executing command:
#  whoami
# sami
# /home/sami/Desktop/GenAI/venv/lib/python3.14/site-packages/langchain_community/tools/shell/tool.py:33: UserWarning: The shell tool has no safeguards by default. Use at your own risk.
#   warnings.warn(

# %% [markdown]
# Highly recommended to add the doc string...
